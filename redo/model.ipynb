# %%
from pymongo import AsyncMongoClient

# %%
client = AsyncMongoClient("mongodb+srv://Irshad:1234567890@cluster0.pw6kh.mongodb.net/")
db = client.Emotional_intelligence

test_collection = db['test']
students_collection = db['students']
answers_collection = db['answers']

# %%
import os
print(os.environ)
# Out:
# environ({'SHELL': '/bin/bash', 'WSL2_GUI_APPS_ENABLED': '1', 'CONDA_EXE': '/home/irshad/anaconda3/bin/conda', '_CE_M': '', 'FNM_ARCH': 'x64', 'WSL_DISTRO_NAME': 'Ubuntu', 'FNM_NODE_DIST_MIRROR': 'https://nodejs.org/dist', 'NAME': 'LAPTOP-OT35U10K', 'PWD': '/mnt/d/workspace/relativeGrade/redo', 'LOGNAME': 'irshad', 'CONDA_PREFIX': '/home/irshad/anaconda3/envs/relgrd', 'MOTD_SHOWN': 'update-motd', 'HOME': '/home/irshad', 'LANG': 'C.UTF-8', 'WSL_INTEROP': '/run/WSL/470_interop', 'FNM_COREPACK_ENABLED': 'false', 'LS_COLORS': 'rs=0:di=01;34:ln=01;36:mh=00:pi=40;33:so=01;35:do=01;35:bd=40;33;01:cd=40;33;01:or=40;31;01:mi=00:su=37;41:sg=30;43:ca=30;41:tw=30;42:ow=34;42:st=37;44:ex=01;32:*.tar=01;31:*.tgz=01;31:*.arc=01;31:*.arj=01;31:*.taz=01;31:*.lha=01;31:*.lz4=01;31:*.lzh=01;31:*.lzma=01;31:*.tlz=01;31:*.txz=01;31:*.tzo=01;31:*.t7z=01;31:*.zip=01;31:*.z=01;31:*.dz=01;31:*.gz=01;31:*.lrz=01;31:*.lz=01;31:*.lzo=01;31:*.xz=01;31:*.zst=01;31:*.tzst=01;31:*.bz2=01;31:*.bz=01;31:*.tbz=01;31:*.
# ...

# %%
await db.list_collection_names()
# Out:
# ['students', 'test']

# %%
# collections =await db.list_collection_names()
# eidb=client["Emotional_intelligence"]
# for i in collections:
#     # eidb[i].insert_many(await db[i].find().to_list(length=None))
#     documents = await db[i].find().to_list(length=None)
#     await eidb[i].insert_many(documents)
#     print(i,documents)
#     pp(documents)
# Out:
# students [{'_id': 1, 'answers': [{'_id': 1, 'answer': 'Emotional intelligence, often referred to as EI, is the remarkable ability to recognize, understand, and manage not only your own emotions but also those of others, allowing for improved personal and professional relationships and greater emotional well-being.'}, {'_id': 2, 'answer': 'The five fundamental components of emotional intelligence include self-awareness, which involves recognizing one’s own emotions and their impact; self-regulation, which is about controlling or redirecting disruptive emotions and adapting to changes; motivation, which signifies the drive to achieve personal and professional goals beyond external rewards; empathy, which is the capacity to understand and share the emotions of others; and social skills, which are the abilities to manage relationships effectively and inspire positive interactions with others.'}, {'_id': 3, 'answer': 'Emotional intelligence is an essential skill for leaders, as it enables
# ...

# %%
#changimg the name to ei
eidb=client["Emotional_intelligence"]

# %%
from pprint import pprint
async for i in students.find():
    pprint(i)
# Out:
# {'_id': 1,
#  'answers': [{'_id': 1,
#               'answer': 'Emotional intelligence, often referred to as EI, is '
#                         'the remarkable ability to recognize, understand, and '
#                         'manage not only your own emotions but also those of '
#                         'others, allowing for improved personal and '
#                         'professional relationships and greater emotional '
#                         'well-being.'},
#              {'_id': 2,
#               'answer': 'The five fundamental components of emotional '
#                         'intelligence include self-awareness, which involves '
#                         'recognizing one’s own emotions and their impact; '
#                         'self-regulation, which is about controlling or '
#                         'redirecting disruptive emotions and adapting to '
#                         'changes; motivation, which signifies the drive to '
# ...

# %%
async for i in  students.find({"_id":3}):
    pprint(i)
# Out:
# {'_id': 3,
#  'answers': [{'_id': 1,
#               'answer': "EI... uh, it's about... controlling emotions and... "
#                         'um, helping in relationships, I think. It’s for '
#                         'leaders to build better teams and, uh... manage '
#                         'stress.'},
#              {'_id': 2,
#               'answer': 'Self-awareness is, like... knowing your emotions, I '
#                         "guess. It's when you realize what you're feeling and "
#                         'how it affects other people, I think.'},
#              {'_id': 3,
#               'answer': "Self-regulation is... um, it's about controlling your "
#                         "emotions when you're angry or upset. Like, keeping "
#                         "calm when you're mad, maybe."},
#              {'_id': 4,
#               'answer': "Empathy is when you understand other people's "
#                         'feelings, right? Like, knowing how they feel and... '
# ...

# %%
for i in range(1,11):
    ans=await students.find_one({'_id': 1,"answers._id":i},{'_id': 0,'answers.$': 1} )
    ans=ans['answers'][0]['answer']
    key=await test.find_one({"_id":i},{"_id":0,"question":0,'mark':0})
    pprint(key['key'])
    pprint(ans)
    print("______________________")
# Out:
# ('Emotional intelligence refers to the ability to identify and manage one’s '
#  'own emotions, as well as the emotions of others.')
# ('Emotional intelligence, often referred to as EI, is the remarkable ability '
#  'to recognize, understand, and manage not only your own emotions but also '
#  'those of others, allowing for improved personal and professional '
#  'relationships and greater emotional well-being.')
# ______________________
# ('The five components of emotional intelligence are self-awareness, '
#  'self-regulation, motivation, empathy, and social skills.')
# ('The five fundamental components of emotional intelligence include '
#  'self-awareness, which involves recognizing one’s own emotions and their '
#  'impact; self-regulation, which is about controlling or redirecting '
#  'disruptive emotions and adapting to changes; motivation, which signifies the '
#  'drive to achieve personal and professional goals beyond external rewards; '
# ...

# %%
i=1
pprint(await test.find_one({"_id":i},{"_id":0,'key':1}))
pprint(await students.find_one({"_id":1,},{"_id":0,'answer':1}))
# Out:
# {'key': 'Emotional intelligence refers to the ability to identify and manage '
#         'one’s own emotions, as well as the emotions of others.'}
# {}

# %%
pprint(await test.find_one({"_id":i},{"_id":0,'ans':1}))
# Out:
# None

# %%
key=await test.find_one({},{"_id":1,'key':1})
ans=await test.find_one({"_id":i},{"_id":0,'ans':1})

# %%
import requests

body = { 'text_1': 'This is an example sentence.', 'text_2': 'This is just another example sentence.' }
api_url = 'https://api.api-ninjas.com/v1/textsimilarity'
response = requests.post(api_url, headers={'X-Api-Key': 'tfy8WN2s8LFktsVpmbOceA==4P963qULQHFlxFUQ'}, json=body)
if response.status_code == requests.codes.ok:
    print(response.text)
else:
    print("Error:", response.status_code, response.text)
# Out:
# {"similarity": 0.8126154541969299}

# %%
ans=await students.find_one({'_id': 1,"answers._id":1},{'_id': 0,'answers.$': 1} )
ans=ans['answers'][0]['answer']
key=await test.find_one({"_id":1},{"_id":0,"question":0,'mark':0})
key=key
pprint((key['key']))
pprint(ans)
print("______________________")
api_url = 'https://api.api-ninjas.com/v1/textsimilarity'
body = { 'text_1':key['key'], 'text_2': ans }
response = requests.post(api_url, headers={'X-Api-Key': 'tfy8WN2s8LFktsVpmbOceA==4P963qULQHFlxFUQ'}, json=body)
if response.status_code == requests.codes.ok:
  print(response.text)
else:
    print("Error:", response.status_code, response.text)
# Out:
# ('Emotional intelligence refers to the ability to identify and manage one’s '
#  'own emotions, as well as the emotions of others.')
# ('Emotional intelligence, often referred to as EI, is the remarkable ability '
#  'to recognize, understand, and manage not only your own emotions but also '
#  'those of others, allowing for improved personal and professional '
#  'relationships and greater emotional well-being.')
# ______________________
# {"similarity": 0.8993223905563354}

# %%
key
# Out:
# {'key': 'Emotional intelligence refers to the ability to identify and manage one’s own emotions, as well as the emotions of others.'}

# %%
async for i in test.find({"_id":1}):
    pprint(i)
    print(i["question"])
# Out:
# {'_id': 1,
#  'key': 'Emotional intelligence refers to the ability to identify and manage '
#         'one’s own emotions, as well as the emotions of others.',
#  'mark': 2,
#  'question': 'What is EI?'}
# What is EI?

# %%
for stu_id in range(1, await students.count_documents({})+1):    
    print("#######",stu_id,"######")
    for questio_no in range(1,11):
        key=await test.find_one({"_id":questio_no},{"_id":0,"question":0,'mark':0})
        question=await test.find_one({"_id":questio_no},{"_id":0,'key':0})

        print(f"Question {question}STUDENT_ID: {stu_id} \t ANSWER: {questio_no}\n {'*'*8}\nKEY:")
        pprint(key['key'])
        print("______________________")

        ans=await students.find_one({'_id': stu_id,"answers._id":questio_no},{'_id': 0,'answers.$': 1} )
        try:
            ans = ans['answers'][0]['answer']
            pprint(ans)

            api_url = 'https://api.api-ninjas.com/v1/textsimilarity'
            body = { 'text_1':key['key'], 'text_2': ans }
            response = requests.post(api_url, headers={'X-Api-Key': 'tfy8WN2s8LFktsVpmbOceA==4P963qULQHFlxFUQ'}, json=body)

            if response.status_code == requests.codes.ok:
                print(response.text, "\n\n")
            else:
                print("Error:", response.status_code, response.text)

        except TypeError:
            ans = ""
            print("------------------")
# Out:
# ####### 1 ######
# Question {'question': 'What is EI?', 'mark': 2}STUDENT_ID: 1 	 ANSWER: 1
#  ********
# KEY:
# ('Emotional intelligence refers to the ability to identify and manage one’s '
#  'own emotions, as well as the emotions of others.')
# ______________________
# ('Emotional intelligence, often referred to as EI, is the remarkable ability '
#  'to recognize, understand, and manage not only your own emotions but also '
#  'those of others, allowing for improved personal and professional '
#  'relationships and greater emotional well-being.')
# {"similarity": 0.8993223905563354}
#
#
# Question {'question': 'What are the 5 components of EI?', 'mark': 2}STUDENT_ID: 1 	 ANSWER: 2
#  ********
# KEY:
# ('The five components of emotional intelligence are self-awareness, '
#  'self-regulation, motivation, empathy, and social skills.')
# ______________________
# ('The five fundamental components of emotional intelligence include '
# ...

# %%
ans=await students.find_one({'_id': 1,"answers._id":1},{'_id': 0,'answers.$': 1} )
ans=ans['answers'][0]['answer']
key=await test.find_one({"_id":1},{"_id":0,"question":0,'mark':0})
print(f"STUDENT_ID: {stu_id} \t ANSWER: {ans_id}\n {'*'*8}\nKEY:")        
pprint(key['key'])
pprint(ans)
# Out:
# STUDENT_ID: 2 	 ANSWER: 1
#  ********
# KEY:
# ('Emotional intelligence refers to the ability to identify and manage one’s '
#  'own emotions, as well as the emotions of others.')
# ('Emotional intelligence, often referred to as EI, is the remarkable ability '
#  'to recognize, understand, and manage not only your own emotions but also '
#  'those of others, allowing for improved personal and professional '
#  'relationships and greater emotional well-being.')

# %%
old_db = client["Distributed_computing"]
new_db = client["Emotional_Intelligence"]

async for collection_name in old_db.list_collection_names():
    old_collection = old_db[collection_name]
    new_collection = new_db[collection_name]
    
    documents = old_collection.find()
    new_collection.insert_many(documents)
# Out:
# /tmp/ipykernel_254258/2581456529.py:4: RuntimeWarning: coroutine 'AsyncDatabase.list_collection_names' was never awaited
#   async for collection_name in old_db.list_collection_names():
# ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[177], line 4
#       1 old_db = client["Distributed_computing"]
#       2 new_db = client["Emotional_Intelligence"]
# ----> 4 async for collection_name in old_db.list_collection_names():
#       5     old_collection = old_db[collection_name]
#       6     new_collection = new_db[collection_name]
#
# TypeError: 'async for' requires an object with __aiter__ method, got coroutine
