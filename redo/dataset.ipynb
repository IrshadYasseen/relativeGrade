# %% [markdown]
# # Import and connections

# %%
from pymongo import AsyncMongoClient
from pprint import pprint
import pandas as pd

# %%
client = AsyncMongoClient("mongodb+srv://Irshad:1234567890@cluster0.pw6kh.mongodb.net/")
db = client.Emotional_intelligence
test_collection = db['test']
students_collection = db['students']
answers_collection = db['answers']

# %% [markdown]
# # qpdf

# %%
key=[]
marks=[]
questions=[]
async for i in test_collection.find({},{'_id':0}).sort("_id", 1):
    # pprint(i)
    key.append(i['key'])
    marks.append(i['mark'])
    questions.append(i['question'])
data={'questions':questions,'key':key,'marks':marks}
qp_df=pd.DataFrame(data)
qp_df
# Out:
#                                    questions  \
# 0                                What is EI?
# 1           What are the 5 components of EI?
# 2            How does EI benefit leadership?
# 3              What is self-awareness in EI?
# 4             What is self-regulation in EI?
# 5               How does empathy enhance EI?
# 6      What is the role of motivation in EI?
# 7        How are social skills linked to EI?
# 8              Can EI be improved over time?
# 9  What is the difference between EI and IQ?
#
#                                                  key  marks
# 0  Emotional intelligence refers to the ability t...      2
# 1  The five components of emotional intelligence ...      2
# 2  EI helps leaders build stronger relationships,...      2
# 3  Self-awareness is the ability to recognize and...      2
# 4  Self-regulation involves controlling or redire...      2
# 5  Empathy allows individuals to understand and s...      2
# ...

# %% [markdown]
# # ansdf

# %%
{'_id': 1,
 'answers': [
     {'_id': 1, 'answer': 'Emotional intelligence, often referred to as EI, is '},
     {'_id': 2, 'answer': 'Emotional intelligence, often referred to as EI, is '}
     ],
  '_id': 2,
 'answers': [
        {'_id': 1, 'answer': 'Emotional intelligence, often referred to as EI, is '},
        {'_id': 3, 'answer': 'Emotional intelligence, often referred to as EI, is '},
 ]
}
# Out:
# []

# %%
cursor = students_collection.find().sort("_id", 1)
result_dict = {doc['_id']: doc for doc in cursor} 
result_dict
# Out:
# {}

# %%
async for s in students_collection.find().sort("_id", 1):
    s['answers']
    pprint(s)
    break
# Out:
# {'_id': 1,
#  'answers': [{'_id': 1,
#               'answer': 'Emotional intelligence, often referred to as EI, is '
#                         'the remarkable ability to recognize, understand, and '
#                         'manage not only your own emotions but also those of '
#                         'others, allowing for improved personal and '
#                         'professional relationships and greater emotional '
#                         'well-being.'},
#              {'_id': 2,
#               'answer': 'The five fundamental components of emotional '
#                         'intelligence include self-awareness, which involves '
#                         'recognizing one’s own emotions and their impact; '
#                         'self-regulation, which is about controlling or '
#                         'redirecting disruptive emotions and adapting to '
#                         'changes; motivation, which signifies the drive to '
# ...

# %%
qp_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Getting each student ans as arrays 
stus=[]
async for s in students_collection.find({},{'_id':0,'answers':1}).sort("_id", 1):
    stus.append((s['answers']))
stus
# Out:
# [[{'_id': 1,
#    'answer': 'Emotional intelligence, often referred to as EI, is the remarkable ability to recognize, understand, and manage not only your own emotions but also those of others, allowing for improved personal and professional relationships and greater emotional well-being.'},
#   {'_id': 2,
#    'answer': 'The five fundamental components of emotional intelligence include self-awareness, which involves recognizing one’s own emotions and their impact; self-regulation, which is about controlling or redirecting disruptive emotions and adapting to changes; motivation, which signifies the drive to achieve personal and professional goals beyond external rewards; empathy, which is the capacity to understand and share the emotions of others; and social skills, which are the abilities to manage relationships effectively and inspire positive interactions with others.'},
#   {'_id': 3,
# ...

# %%
for stu  in stus:
    print("Processing student...")
    for ans in stu:
        print("\t Processing answer\n" )
        print(f"\t {ans['answer']}")
# Out:
# Processing student...
# 	 Processing answer
#
# 	 Emotional intelligence, often referred to as EI, is the remarkable ability to recognize, understand, and manage not only your own emotions but also those of others, allowing for improved personal and professional relationships and greater emotional well-being.
# 	 Processing answer
#
# 	 The five fundamental components of emotional intelligence include self-awareness, which involves recognizing one’s own emotions and their impact; self-regulation, which is about controlling or redirecting disruptive emotions and adapting to changes; motivation, which signifies the drive to achieve personal and professional goals beyond external rewards; empathy, which is the capacity to understand and share the emotions of others; and social skills, which are the abilities to manage relationships effectively and inspire positive interactions with others.
# 	 Processing answer
#
# ...

# %%
# Out:
#   Cell In[113], line 1
#     async l=[]
#           ^
# SyntaxError: invalid syntax

# %%
async for i in test_collection.find().sort("_id", 1):
    print(i['question'])
    for s in students_collection.find().sort("_id", 1):
        print(s)
        l.append([i['question'],i['key']])
l
# Out:
# What is EI?
# What are the 5 components of EI?
# How does EI benefit leadership?
# What is self-awareness in EI?
# What is self-regulation in EI?
# How does empathy enhance EI?
# What is the role of motivation in EI?
# How are social skills linked to EI?
# Can EI be improved over time?
# What is the difference between EI and IQ?
# []

# %%
async for i in students_collection.find().sort("_id", -1):
    print(i['answers'])
# Out:
# [{'_id': 1, 'answer': "EI... uh, it's about... controlling emotions and... um, helping in relationships, I think. It’s for leaders to build better teams and, uh... manage stress."}, {'_id': 2, 'answer': "Self-awareness is, like... knowing your emotions, I guess. It's when you realize what you're feeling and how it affects other people, I think."}, {'_id': 3, 'answer': "Self-regulation is... um, it's about controlling your emotions when you're angry or upset. Like, keeping calm when you're mad, maybe."}, {'_id': 4, 'answer': "Empathy is when you understand other people's feelings, right? Like, knowing how they feel and... um... using that to talk better or help them."}, {'_id': 5, 'answer': "Motivation in EI, I think, is... when you're driven to do things for yourself. Not just for rewards, but like, to achieve something for yourself. I’m not totally sure."}, {'_id': 6, 'answer': 'Social skills are... when you know how to talk to people and make good relationships. It helps in resolvi
# ...

# %%
l
# Out:
# []

# %%
q=await test_collection.find_one(
                {"_id": 1}, {"_id": 0, "question": 0, 'mark': 0}
            )
pprint(q)
# Out:
# {'key': 'Emotional intelligence refers to the ability to identify and manage '
#         'one’s own emotions, as well as the emotions of others.'}

# %%
async for i in students_collection.find().sort("_id",1):
    pprint(i['answers'])
# Out:
# [{'_id': 1,
#   'answer': 'Emotional intelligence, often referred to as EI, is the '
#             'remarkable ability to recognize, understand, and manage not only '
#             'your own emotions but also those of others, allowing for improved '
#             'personal and professional relationships and greater emotional '
#             'well-being.'},
#  {'_id': 2,
#   'answer': 'The five fundamental components of emotional intelligence include '
#             'self-awareness, which involves recognizing one’s own emotions and '
#             'their impact; self-regulation, which is about controlling or '
#             'redirecting disruptive emotions and adapting to changes; '
#             'motivation, which signifies the drive to achieve personal and '
#             'professional goals beyond external rewards; empathy, which is the '
#             'capacity to understand and share the emotions of others; and '
# ...
